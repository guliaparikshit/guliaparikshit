# %%
print("jaat")
# Out:
# jaat

# %%
a=[1,2,3,4,5,6,7]

# %%
print(a[::-1])
# Out:
# [7, 6, 5, 4, 3, 2, 1]

# %%
print(a)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
a=12

# %%
print 1
# Out:
#   Cell In[6], line 1
#     print 1
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print(a)
# Out:
# 12

# %% [markdown]
# object oriented programming system

# %%
a=1

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type("parikshit"))
# Out:
# <class 'str'>

# %%
class test:
# Out:
#   Cell In[12], line 1
#     class test:
#                ^
# SyntaxError: incomplete input

# %%
class test01:
    pass

# %%
a=test01()

# %%
type(a)
# Out:
# __main__.test01

# %%
print(type(a))
# Out:
# <class '__main__.test01'>

# %% [markdown]
# a ab class test01 se belong krega

# %%
class parikshit:
    
    def welcome_msg():
        print("welcome to parikshit's house")

# %%
b=parikshit()

# %%
b

# %%
type(b)
# Out:
# __main__.parikshit

# %%
b.welcome_msg()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 b.welcome_msg()
#
# TypeError: parikshit.welcome_msg() takes 0 positional arguments but 1 was given

# %% [markdown]
# **class ke ander function banana hai toh pointer reference dena padega jaise ki self **

# %%
class parikshit:
    
    def welcome_msg(self):
        print("welcome to parikshit's house")

# %%
b=parikshit()

# %%
b.welcome_msg()
# Out:
# welcome to parikshit's house

# %%
c=parikshit()

# %%
c.welcome_msg()
# Out:
# welcome to parikshit's house

# %% [markdown]
# constructor

# %%
class pwskills:
    
    def __init__(self,phone_number,email_id,student_id):
        
        self.phone_number=phone_number
        self.email_id=email_id
        self.student_id=student_id
        
    def return_student_details(self):
        return self.phone_number,self.email_id,self.student_id

# %%
rohan=pwskills()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 rohan=pwskills()
#
# TypeError: pwskills.__init__() missing 3 required positional arguments: 'phone_number', 'email_id', and 'student_id'

# %%
rohan=pwskills(8901055872,"rohandeswal123@gmail.com",234789)

# %%
rohan.return_student_details()
# Out:
# (8901055872, 'rohandeswal123@gmail.com', 234789)

# %%
sudhir=pwskills(6789098765,"sudhirryu34@gmail.com",567890)

# %%
sudhir.return_student_details()
# Out:
# (6789098765, 'sudhirryu34@gmail.com', 567890)

# %%
sudhir.phone_number
# Out:
# 6789098765

# %%
sudhir.email_id
# Out:
# 'sudhirryu34@gmail.com'

# %%
rohan.student_id
# Out:
# 234789

# %% [markdown]
# **polymorphism**

# %%
def foody(a,b):
    return a+b

# %%
foody(45,90)
# Out:
# 135

# %%
foody("sudh","kumar")
# Out:
# 'sudhkumar'

# %% [markdown]
# sometimes behaving like addition sometimes concatination depending on the inputs its polymorphism

# %%
class data_science:
    def syallabus(self):
        print("this is my syallabus for data science")

# %%
class web_dev:
    def syallabus(self):
        print("this is my syallabus for web dev")

# %%
def class_parcer(class_obj):
    for i in class_obj:
        i.syallabus()

# %%
obj_data_science=data_science()

# %%
obj_web_dev=web_dev()

# %%
class_obj=[obj_data_science,obj_web_dev]

# %%
class_parcer(class_obj)
# Out:
# this is my syallabus for data science
# this is my syallabus for web dev

# %% [markdown]
# **encapsulation**

# %%
class test:
    def __init__(self,a,b):
        self.a=a
        self.b=b

# %%
t=test(45,87)

# %%
t.a
# Out:
# 45

# %%
t.b
# Out:
# 87

# %%
t.a=765

# %%
t.a
# Out:
# 765

# %%
class car:
    def __init__(self,year,make,model):
        self.__year=year
        self.__make=make
        self.__model=model

# %%
obj_car=car(2021,"toyota","innova")

# %%
obj_car.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 obj_car.year
#
# AttributeError: 'car' object has no attribute 'year'

# %%
obj_car._car__year
# Out:
# 2021

# %%
obj_car._car__year=345

# %%
obj_car._car__year
# Out:
# 345

# %% [markdown]
# **inheritance**

# %%
class parent():
    
    def test_parent(self):
        print("this is my parent class")

# %%
class child(parent):
    pass

# %%
child_obj=child()

# %%
child_obj.test_parent()
# Out:
# this is my parent class

# %% [markdown]
# **multilabel inheritance**

# %%
class class1():
    def test_class1(self):
        print("this is my class 1")

# %%
class class2(class1):
    def test_class2(self):
        print("this is my class 2")

# %%
class class3(class2):
    def test_class3(self):
        print("this is my class 3")

# %%
obj_class3=class3()

# %%
obj_class3.test_class1()
# Out:
# this is my class 1

# %%
obj_class3.test_class2()
# Out:
# this is my class 2

# %% [markdown]
# **multiple inheritance**

# %%
class class1():
    def test_class1(self):
        print("this is my class1")

# %%
class class2():
    def test_class2(self):
        print("this is my class2")

# %%
class class3(class1,class2):
    pass

# %%
obj_class3=class3()

# %%
obj_class3.test_class1()
# Out:
# this is my class1

# %%
obj_class3.test_class2()
# Out:
# this is my class2

# %% [markdown]
# **abstraction**

# %%
import abc

# %%
import abc

class pwskills():
    
    @abc.abstractmethod
    def student_details(self):
        pass
    
    @abc.abstractmethod
    def student_assignment(self):
        pass
    
    @abc.abstractmethod
    def student_marks(self):
        pass

# %%
class datascience(pwskills):
    def student_details(self):
        return "this is student details of data science"
    
    def student_marks(self):
        return "these are the marks of students in data science"

# %%
class webdev(pwskills):
    def student_details(self):
        return "this is student details of web dev"
    
    def student_marks(self):
        return "these are the marks of students in web dev"

# %%
ds=datascience()
ds.student_marks()
# Out:
# 'these are the marks of students in data science'

# %%
ds.student_details()
# Out:
# 'this is student details of data science'

# %%
wb=webdev()
wb.student_details()
# Out:
# 'this is student details of web dev'

# %% [markdown]
# **decorators**

# %%
def test1():
    print(4+5)

# %%
test1()
# Out:
# 9

# %%
def test1():
    print("this is the start of the function")
    print(4+5)
    print("this is the end of my function")

# %%
test1()
# Out:
# this is the start of the function
# 9
# this is the end of my function

# %%
def deco(func):
    def inner_deco():
        print("this is the start of my function")
        func()
        print("this is the end of my function")
    return inner_deco

# %%
def test02():
    print(45+45)

# %%
test02()
# Out:
# 90

# %%
@deco
def test03():
    print(56+76)

# %%
test03()
# Out:
# this is the start of my function
# 132
# this is the end of my function

# %%
test02()
# Out:
# 90

# %%
#time complexity

# %%
import time
def timer_test(func):
    def timer_test_inner():
        start=time.time()
        func()
        end=time.time()
        print(end-start)
    return timer_test_inner

# %%
@timer_test
def test2():
    print(4+4)

# %%
test2()
# Out:
# 8
# 8.511543273925781e-05

# %%
@timer_test
def test3():
    for i in range(1000):
        pass

# %%
test3()
# Out:
# 2.6226043701171875e-05

# %% [markdown]
# **class methods**

# %%
class pwskills:
    def __init__(self,name,email):
        self.name=name
        self.email=email
        
    def students_details(self):
        print(self.name,self.email)

# %%
pw=pwskills("parikshit","parikshitgulia38@gmail.com")

# %%
pw.email
# Out:
# 'parikshitgulia38@gmail.com'

# %%
pw.name
# Out:
# 'parikshit'

# %%
pw.students_details()
# Out:
# parikshit parikshitgulia38@gmail.com

# %%
class pwskills1:
    def __init__(self,name,email):
        self.name=name
        self.email=email
        
    @classmethod
    def details(cls,name,email):
        return cls(name,email)
        
    def students_details(self):
        print(self.name,self.email)

# %%
pw1=pwskills1.details("jaat","jaat4878@gmail.com")

# %%
pw1.email
# Out:
# 'jaat4878@gmail.com'

# %%
pw1.name
# Out:
# 'jaat'

# %%
pw1.students_details()
# Out:
# jaat jaat4878@gmail.com

# %% [markdown]
# **ab agr me name email ki jagh 1 bhi dal du and call kru name email same hi rhega overloading hogai init function ki using decorator like class methods**

# %%
class pwskills2:
    mobile_number=9876543
    
    
    def __init__(self,name,email):
        self.name=name
        self.email=email
        
    @classmethod
    def details(cls,name,email):
        return cls(name,email)
        
    def students_details(self):
        print(self.name,self.email,pwskills2.mobile_number)

# %%
pwskills2.mobile_number
# Out:
# 9876543

# %%
pw2=pwskills2.details("sohan","sohan45@gmail.com")

# %%
pw2.students_details()
# Out:
# sohan sohan45@gmail.com 9876543

# %% [markdown]
# **static method**

# %%
class school:
    def student_details(self , name , email , phone):
        print(name,email,phone)

# %%
sh=school()

# %%
sh.student_details("jaat","jaaat@gmail.com",98765)
# Out:
# jaat jaaat@gmail.com 98765

# %%
class school1:
    def student_details(self , name , email , phone):
        print(name,email,phone)
        
    @staticmethod
    def mentor_class(list_mentor):
        print(list_mentor)

# %%
school1.mentor_class(["aman","jaat","deswal"])
# Out:
# ['aman', 'jaat', 'deswal']

# %% [markdown]
# **special magic dunders method**

# %%
dir(int)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
# ...

# %%
a=10

# %%
a+6
# Out:
# 16

# %%
a.__add__(6)
# Out:
# 16

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
class jaat:
    def __init__(self):
        print("this is init")

# %%
ja=jaat()
# Out:
# this is init

# %%
class pwskills:
    def __init__(self):
        self.number=456789

# %%
pw=pwskills()

# %%
print(pw)

# %%
class pwskills:
    def __init__(self):
        self.number=456789
        
    def __str__(self):
        return "this is magic method for a no"

# %%
pw=pwskills()

# %%
print(pw)
# Out:
# this is magic method for a no

# %% [markdown]
# **property decorators getters , setters , delete**

# %%
class pwskills:
    def __init__(self,course_price,course_name):
        self.__course_price=course_price
        self.course_name=course_name

# %%
pw=pwskills(3500,"Data Science")

# %%
pw.course_name
# Out:
# 'Data Science'

# %%
pw.course_price
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[195], line 1
# ----> 1 pw.course_price
#
# AttributeError: 'pwskills' object has no attribute 'course_price'

# %%
pw._pwskills__course_price
# Out:
# 3500

# %% [markdown]
# **class name pta hia tbhi dikhega ye sbh**

# %%
class pwskills:
    def __init__(self,course_price,course_name):
        self.__course_price=course_price
        self.course_name=course_name
        
    @property
    def course_price_access(self):
        return self.__course_price

# %%
p1=pwskills(456,"data")

# %%
p1.course_price_access
# Out:
# 456

# %%
class pwskills:
    def __init__(self,course_price,course_name):
        self.__course_price=course_price
        self.course_name=course_name
        
    @property
    def course_price_access(self):
        return self.__course_price
    
    @course_price_access.setter
    def course_price_set(self,price):
        if price<=3500:
            pass
        else:
            self.__course_price=price

# %%
p2=pwskills(3500,"science")

# %%
p2.course_price_set=2300

# %%
p2.course_price_access
# Out:
# 3500

# %%
p2.course_price_set=4000

# %%
p2.course_price_access
# Out:
# 4000

# %%
class pwskills:
    def __init__(self,course_price,course_name):
        self.__course_price=course_price
        self.course_name=course_name
        
    @property
    def course_price_access(self):
        return self.__course_price
    
    @course_price_access.setter
    def course_price_set(self,price):
        if price<=3500:
            pass
        else:
            self.__course_price=price
            
    @course_price_access.deleter
    def course_price_delete(self):
        del self.__course_price

# %%
p3=pwskills(3500,"data")

# %%
p3.course_price_delete
# Out:
# 3500

# %%
del p3.course_price_delete

# %%
p3.course_price_access
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[223], line 1
# ----> 1 p3.course_price_access
#
# Cell In[211], line 8, in pwskills.course_price_access(self)
#       6 @property
#       7 def course_price_access(self):
# ----> 8     return self.__course_price
#
# AttributeError: 'pwskills' object has no attribute '_pwskills__course_price'

# %% [markdown]
# **OPPS COMPLETED**
